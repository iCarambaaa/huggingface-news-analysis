# %%
# install transformers library (uncomment the line below if needed)

#!pip install datasets transformers[sentencepiece]

# %%
# import pipeline
from transformers import pipeline

# choose the language
lang = "ru"

# create translator object 
translator = pipeline("translation", model=f"Helsinki-NLP/opus-mt-{lang}-en")

# test the model
translator("Российские банки за февраль-март снизили объем закупки золото.")
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:196: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# [{'translation_text': 'Russian banks reduced the volume of gold in February-March.'}]

# %%
# make the API call using requests library
import requests

url = "https://free-news.p.rapidapi.com/v1/search"

# define query parameters
query = "золото"

querystring = {"q": query,"lang": lang}

headers = {
	"X-RapidAPI-Host": "free-news.p.rapidapi.com",
	"X-RapidAPI-Key": "SECRET_KEY"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)

# %%
import pandas as pd 
import json
from pandas import json_normalize

# Use json_normalize() to convert JSON to DataFrame
dict = json.loads(response.text)
df = json_normalize(dict['articles']) 
display(df)
# Out:
#                                                title  \
# 0  Дзюдо. Как Елдос Сметов из Казахстана идет к н...
# 1  Великие олимпийские моменты. Плавание. Ле Кло–...
# 2  Российские банки за февраль-март снизили объем...
# 3  Reuters: Шри-Ланка на фоне дефицита топлива ку...
# 4  Fox News: «машина возмущения» и «культура отме...
# 5  Хоккей. Чемпионат мира-2022. Золото – у сборно...
# 6  Легкая атлетика. «Бриллиантовая лига»-2022. Юд...
# 7  Экс-президенту Молдовы предъявили обвинение в ...
# 8  «Даже политикой это назвать не могу — просто г...
# 9  Жажда мести Салаха, поход Бензема за «Золотым ...
#
#                         author       published_date published_date_precision  \
# 0                         None  2022-05-27 10:34:24                     full
# 1                         None  2022-05-27 07:01:42                     full
# 2                     Lenta.ru  2022-05-30 06:56:15                     full
# 3                         None  2022-05-28 23:01:38                     full
# 4                         None  2022-05-28 00:00:00                     date
# 5                         None  2022-05-30 06:54:29                     full
# 6                         None  2022-05-26 19:30:00                     full
# 7  \nАвтор\nЕлизавета Фомина\n  2022-05-25 22:57:49                     full
# 8           Елена Вайцеховская  2022-05-26 11:16:28                     full
# 9             Борислав Головин  2022-05-27 19:49:43                     full
#
#                                                 link     clean_url  \
# 0  https://olympics.com/ru/news/dzyudo-kak-eldos-...  olympics.com
# 1  https://olympics.com/ru/news/velikie-olimpiisk...  olympics.com
# 2  https://yandex.ru/news/story/Rossijskie_banki_...     yandex.ru
# 3           https://news.mail.ru/economics/51518726/       mail.ru
# 4  https://russian.rt.com/inotv/2022-05-28/Fox-Ne...        rt.com
# 5  https://olympics.com/ru/news/hokkei-chempionat...  olympics.com
# 6  https://olympics.com/ru/news/legkaya-atletika-...  olympics.com
# 7  https://www.dw.com/ru/eks-prezidentu-moldovy-p...        dw.com
# 8  https://russian.rt.com/sport/article/1007714-c...        rt.com
# 9  https://russian.rt.com/sport/article/1008477-s...        rt.com
#
#                                              summary         rights  rank  \
# 0  Елдос Сметов — один из самых популярных дзюдои...   olympics.com   897
# 1  Чад Ле Кло преподнес один из самых больших сюр...   olympics.com   897
# 2                                                         yandex.ru   336
# 3  Как заявил министр энергетики Шри-Ланки Канчан...        mail.ru   631
# 4  РИККИ ЖЕРВЕ, комик: Но когда мы видим эту само...         rt.com   506
# 5  29 мая в решающем матче чемпионата мира-2022 п...   olympics.com   897
# 6  В субботу, 28 мая, в Юджине (США) пройдет трет...   olympics.com   897
# 7  Прокуроры запросили ордер на арест бывшего пре...         dw.com   387
# 8  В «грязной возне» с отстранением российских сп...  RT на русском   506
# 9  28 мая в финале Лиги чемпионов в Сен-Дени сойд...  RT на русском   506
#
#        topic country language  \
# 0       news      CH       ru
# 1       news      CH       ru
# 2   business      RU       ru
# 3  economics      RU       ru
# 4       news      RU       ru
# 5       news      CH       ru
# 6       news      CH       ru
# 7       news      DE       ru
# 8       news      RU       ru
# 9       news      RU       ru
#
#                                              authors  \
# 0                                                 []
# 1                                                 []
# 2                                         [Lenta.ru]
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7  [Deutsche Welle, Www.Dw.Com, Автор, Александр ...
# 8                               [Елена Вайцеховская]
# 9                                 [Борислав Головин]
#
#                                                media  is_opinion  \
# 0  https://img.olympicchannel.com/images/image/pr...       False
# 1  https://img.olympicchannel.com/images/image/pr...       False
# 2  https://yastatic.net/s3/home/logos/share/share...       False
# 3  https://resizer.mail.ru/p/9176c745-c598-5fe2-9...       False
# 4  https://cdni.rt.com/inotv/s/content/0/f/q/k/16...       False
# 5  https://img.olympicchannel.com/images/image/pr...       False
# 6  https://img.olympicchannel.com/images/image/pr...       False
# 7       https://static.dw.com/image/17619211_303.jpg       False
# 8  https://cdni.rt.com/russian/images/2022.05/art...       False
# 9  https://cdni.rt.com/russian/images/2022.05/art...       False
#
#   twitter_account     _score                               _id
# 0       @Olympics  15.853716  0e4afb852fd809e4fa2d7372d6e48ec0
# 1       @Olympics  13.888209  9eaaeb755c72316b472fb5a828cd5671
# 2            None  13.863571  92b15a533ac068bcc83ee2c790184134
# 3            None  11.467201  ae5474261fee7f3660096ae30b6cd61b
# 4       @RT_InoTV   9.704652  54ee2b90c3199d7fbc9054de42eb1ac1
# 5       @Olympics   8.880980  ce52c3ad328c3b3f8b788be677279b6b
# 6       @Olympics   8.684689  30a798a0157a92abf806a509cd943c9e
# 7     @dw_russian   8.661152  c368bb8b858dea93f63d45fb2499ddac
# 8     @RT_russian   5.896547  17127908bcae9543e636a81d7049221d
# 9     @RT_russian   5.278027  9a1ae322afe4614c30c8d65cc22390f8

# %%
# extract the summary column and loop through it creating the translations - save them as a list

summary_df = df["summary"]

i = 0
translated = []

for text in summary_df:
  print(20*"-")
  print(i)
  tr = translator(text)
  print(tr)
  translated.append(tr)
  i += 1
# Out:
# --------------------
# 0
# [{'translation_text': 'Eldos Smetov is one of the most popular judoists in the CIS, a star in Kazakh sports, and a man who follows his third Olympic medal in Paris-2024. His journey is quite dramatic, since at previous Games in Rio de Janeiro and Tokyo he was unable to win gold by taking medals of other virtues.'}]
# --------------------
# 1
# [{'translation_text': 'Chad, Le Clo, presented one of the biggest surprises at the Olympic Games in London, ahead of the legendary Michael Phelps in a 200 m batherfly final swim. The South African swimmer seriously announced himself in the international arena at the Youth Olympics in Singapore in 2010. 18-year-old Le Clo won five medals, including gold at 200 m integrated swimming distance. A few months later, he won his first gold World Short Water Championship in Dubai at a distance of 200 m.'}]
# --------------------
# 2
# [{'translation_text': "It's okay. It's okay, it's okay, it's okay."}]
# --------------------
# 3
# [{'translation_text': 'According to Sri Lanka &apos; s Minister of Energy, Kanchana Widgeseker, his country had requested support for the import of crude oil and petroleum products to many countries, including Russia. 90,000 tons of Siberian Light oil will be delivered through the Dubai-based company Royal Energy, which will allow the resumption of the country &apos; s only refinery, which had to be shut down on 25 March.'}]
# --------------------
# 4
# [{'translation_text': 'RICKS JERVE, COMICK: But when we see this self-reclamation, when celebrities go through these silly polls and they say, "Show me that you have a time machine, what will you do first?" They all say, "Oh, I\'ll go back and kill Hitler!" Really? You go back to the past and buy shares of Microsoft, you fucking liar!'}]
# --------------------
# 5
# [{'translation_text': "On 29 May, at the World Cup's 2022 World Championships, the Finnish team won the Canadians and added the second major title of the current season to the Olympic gold game in Beijing. After two periods of 0:1, Jukka Jalonen's team broke the game in the third 20 minutes. Two of Michael Granlund's teams, who had been abandoned in the majority, and Yoel Armia had already made the arena in Tampere look forward to winning, especially since Canadians in the third period were forced to come out at the Matt Tomkins Championship because of the injury of Chris Dridge, who had played a beautiful game."}]
# --------------------
# 6
# [{'translation_text': 'On Saturday, May 28, in Eugene, U.S.A., there will be the third stage of the "Brilliant League" 2022. These competitions are the real classic "Kings of Sport." They have been held since 1975, in memory of Steve Prefontaine\'s famous mid-long run, and the most prestigious discipline is one mile (1,609 m) for men, bearing the name of his coach, Bill Bauerman, and traditionally gathering the strongest number of participants. This year, at the Heyward Field Stadium (in July, he will become the main sports target of the World Light Athletics 2022) World Cup, the Tokyo-2020 champion, Yakob Ingebrittssen of Norway, and the 2019 World Champion of Timothy Cheruyote of Kenya.'}]
# --------------------
# 7
# [{'translation_text': 'The prosecutors requested a warrant for the arrest of the former President of Moldova, Igor Dodon, for 30 days, accused of treason and corruption; the former President of Moldova, Igor Dodon, former President of Moldova, Igor Dodon, known for his pro-Russian position, charged him with corruption and treason; the Attorney-General &apos; s Office of the Republic requested a warrant for Dodon &apos; s arrest for 30 days; this was reported on Wednesday, 25 May by the spokesperson of the Attorney-General &apos; s Office, Marianne Kirpek; she said that the criminal case against the ex-President had been brought under four articles: in addition to passive corruption and State change, it was also a matter of illegal enrichment and obtaining the financing of a political party from a criminal organization.'}]
# --------------------
# 8
# [{'translation_text': 'Even the International Navigation Federation was involved in the "foul climb" of Russian athletes, as stated in an interview by RT, the head coach of the national team, Sergei Chepik. He said that the FINA Bureau refused to listen to even the four-time Olympic champion Vladimir Salnikov, and the specialist also explained how the gathering was taking place in Kabardinka, explained why Eugenia Rylov, Anton Chupkov and Clement Colesnikov were not in favour of his absence, and shared the idea of domestic startups where swimmers would be able to earn decent prizes.'}]
# --------------------
# 9
# [{'translation_text': "On 28 May, in the finals of the Saint-Deni Champion League, there will be Real and Liverpool, and the Mercisaids will try to take revenge from the rival for defeat in a decisive standoff against the tournament four years ago, when Mohammed Salah left the field because of an injury in the first half of the season. Karim Benzem will try to defeat Kristian Ronalde's achievement and give himself the title of lead candidate for the Golden Ball, and the Maddians' mentor Carlo Anchelotti may be the first coach in history to win the main Eurocup four times."}]

# %%
# extract the title column and loop through it creating the translations - save them as a list
title_df = df["title"]

i = 0
translated_title = []

for text in title_df:
  print(20*"-")
  print(i)
  tr = translator(text)
  print(tr)
  translated_title.append(tr)
  i += 1
# Out:
# --------------------
# 0
# [{'translation_text': 'Judo, how Eldos Smetov from Kazakhstan goes to the new Olympic dream'}]
# --------------------
# 1
# [{'translation_text': 'The great Olympic moments, swimming, Le Clo - 2012'}]
# --------------------
# 2
# [{'translation_text': 'Russian banks for February-March reduced their investment in gold: Yandex.'}]
# --------------------
# 3
# [{'translation_text': 'Reuters: Sri Lanka will buy $72.6 million worth of oil from Russia in the face of fuel shortages.'}]
# --------------------
# 4
# [{'translation_text': 'Fox News: "The Machine of Disturbance" and "Culture of Abolition" — American liberals fighting humor — InoTV'}]
# --------------------
# 5
# [{'translation_text': 'Hockey, World Championship 2022.'}]
# --------------------
# 6
# [{'translation_text': 'Light Athlete, Brilliant League 2022, Eugene, what to wait for, where to watch'}]
# --------------------
# 7
# [{'translation_text': 'The Ex-President of Moldova was charged with corruption and treason'}]
# --------------------
# 8
# [{'translation_text': '"I can\'t even call it politics, just a dirty streak": FINA\'s Championship, Cabardinca Collections, and prizes.'}]
# --------------------
# 9
# [{'translation_text': "The thirst for Salah's revenge, Benzem's ride for the Golden Ball, and Anchelotti's luck: What's interesting about the finals of the Champions League?"}]

# %%
# extract the translated string from the translated object and save to a new list (both title and summary) 

transleted_summary_list = []

for tr in translated:
  #print(20*"-")
  #print(tr[0]["translation_text"])
  transleted_summary_list.append(tr[0]["translation_text"])

transleted_title_list = []

for tr in translated_title:
  #print(20*"-")
  #print(tr[0]["translation_text"])
  transleted_title_list.append(tr[0]["translation_text"])

# %%
# reasign the original colums to new ones and asign the translated strings to original colums

df["summary_org"] = df["summary"]
df["summary"] = transleted_summary_list
df["title_org"] = df["title"]
df["title"] = transleted_title_list
df
# Out:
#                                                title  \
# 0  Judo, how Eldos Smetov from Kazakhstan goes to...
# 1  The great Olympic moments, swimming, Le Clo - ...
# 2  Russian banks for February-March reduced their...
# 3  Reuters: Sri Lanka will buy $72.6 million wort...
# 4  Fox News: "The Machine of Disturbance" and "Cu...
# 5                   Hockey, World Championship 2022.
# 6  Light Athlete, Brilliant League 2022, Eugene, ...
# 7  The Ex-President of Moldova was charged with c...
# 8  "I can't even call it politics, just a dirty s...
# 9  The thirst for Salah's revenge, Benzem's ride ...
#
#                         author       published_date published_date_precision  \
# 0                         None  2022-05-27 10:34:24                     full
# 1                         None  2022-05-27 07:01:42                     full
# 2                     Lenta.ru  2022-05-30 06:56:15                     full
# 3                         None  2022-05-28 23:01:38                     full
# 4                         None  2022-05-28 00:00:00                     date
# 5                         None  2022-05-30 06:54:29                     full
# 6                         None  2022-05-26 19:30:00                     full
# 7  \nАвтор\nЕлизавета Фомина\n  2022-05-25 22:57:49                     full
# 8           Елена Вайцеховская  2022-05-26 11:16:28                     full
# 9             Борислав Головин  2022-05-27 19:49:43                     full
#
#                                                 link     clean_url  \
# 0  https://olympics.com/ru/news/dzyudo-kak-eldos-...  olympics.com
# 1  https://olympics.com/ru/news/velikie-olimpiisk...  olympics.com
# 2  https://yandex.ru/news/story/Rossijskie_banki_...     yandex.ru
# 3           https://news.mail.ru/economics/51518726/       mail.ru
# 4  https://russian.rt.com/inotv/2022-05-28/Fox-Ne...        rt.com
# 5  https://olympics.com/ru/news/hokkei-chempionat...  olympics.com
# 6  https://olympics.com/ru/news/legkaya-atletika-...  olympics.com
# 7  https://www.dw.com/ru/eks-prezidentu-moldovy-p...        dw.com
# 8  https://russian.rt.com/sport/article/1007714-c...        rt.com
# 9  https://russian.rt.com/sport/article/1008477-s...        rt.com
#
#                                              summary         rights  rank  \
# 0  Eldos Smetov is one of the most popular judois...   olympics.com   897
# 1  Chad, Le Clo, presented one of the biggest sur...   olympics.com   897
# 2        It's okay. It's okay, it's okay, it's okay.      yandex.ru   336
# 3  According to Sri Lanka &apos; s Minister of En...        mail.ru   631
# 4  RICKS JERVE, COMICK: But when we see this self...         rt.com   506
# 5  On 29 May, at the World Cup's 2022 World Champ...   olympics.com   897
# 6  On Saturday, May 28, in Eugene, U.S.A., there ...   olympics.com   897
# 7  The prosecutors requested a warrant for the ar...         dw.com   387
# 8  Even the International Navigation Federation w...  RT на русском   506
# 9  On 28 May, in the finals of the Saint-Deni Cha...  RT на русском   506
#
#        topic country language  \
# 0       news      CH       ru
# 1       news      CH       ru
# 2   business      RU       ru
# 3  economics      RU       ru
# 4       news      RU       ru
# 5       news      CH       ru
# 6       news      CH       ru
# 7       news      DE       ru
# 8       news      RU       ru
# 9       news      RU       ru
#
#                                              authors  \
# 0                                                 []
# 1                                                 []
# 2                                         [Lenta.ru]
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7  [Deutsche Welle, Www.Dw.Com, Автор, Александр ...
# 8                               [Елена Вайцеховская]
# 9                                 [Борислав Головин]
#
#                                                media  is_opinion  \
# 0  https://img.olympicchannel.com/images/image/pr...       False
# 1  https://img.olympicchannel.com/images/image/pr...       False
# 2  https://yastatic.net/s3/home/logos/share/share...       False
# 3  https://resizer.mail.ru/p/9176c745-c598-5fe2-9...       False
# 4  https://cdni.rt.com/inotv/s/content/0/f/q/k/16...       False
# 5  https://img.olympicchannel.com/images/image/pr...       False
# 6  https://img.olympicchannel.com/images/image/pr...       False
# 7       https://static.dw.com/image/17619211_303.jpg       False
# 8  https://cdni.rt.com/russian/images/2022.05/art...       False
# 9  https://cdni.rt.com/russian/images/2022.05/art...       False
#
#   twitter_account     _score                               _id  \
# 0       @Olympics  15.853716  0e4afb852fd809e4fa2d7372d6e48ec0
# 1       @Olympics  13.888209  9eaaeb755c72316b472fb5a828cd5671
# 2            None  13.863571  92b15a533ac068bcc83ee2c790184134
# 3            None  11.467201  ae5474261fee7f3660096ae30b6cd61b
# 4       @RT_InoTV   9.704652  54ee2b90c3199d7fbc9054de42eb1ac1
# 5       @Olympics   8.880980  ce52c3ad328c3b3f8b788be677279b6b
# 6       @Olympics   8.684689  30a798a0157a92abf806a509cd943c9e
# 7     @dw_russian   8.661152  c368bb8b858dea93f63d45fb2499ddac
# 8     @RT_russian   5.896547  17127908bcae9543e636a81d7049221d
# 9     @RT_russian   5.278027  9a1ae322afe4614c30c8d65cc22390f8
#
#                                          summary_org  \
# 0  Елдос Сметов — один из самых популярных дзюдои...
# 1  Чад Ле Кло преподнес один из самых больших сюр...
# 2
# 3  Как заявил министр энергетики Шри-Ланки Канчан...
# 4  РИККИ ЖЕРВЕ, комик: Но когда мы видим эту само...
# 5  29 мая в решающем матче чемпионата мира-2022 п...
# 6  В субботу, 28 мая, в Юджине (США) пройдет трет...
# 7  Прокуроры запросили ордер на арест бывшего пре...
# 8  В «грязной возне» с отстранением российских сп...
# 9  28 мая в финале Лиги чемпионов в Сен-Дени сойд...
#
#                                            title_org
# 0  Дзюдо. Как Елдос Сметов из Казахстана идет к н...
# 1  Великие олимпийские моменты. Плавание. Ле Кло–...
# 2  Российские банки за февраль-март снизили объем...
# 3  Reuters: Шри-Ланка на фоне дефицита топлива ку...
# 4  Fox News: «машина возмущения» и «культура отме...
# 5  Хоккей. Чемпионат мира-2022. Золото – у сборно...
# 6  Легкая атлетика. «Бриллиантовая лига»-2022. Юд...
# 7  Экс-президенту Молдовы предъявили обвинение в ...
# 8  «Даже политикой это назвать не могу — просто г...
# 9  Жажда мести Салаха, поход Бензема за «Золотым ...

# %%
# save the dataframe to a CSV file

df.to_csv(f"{lang}-translated.csv")
